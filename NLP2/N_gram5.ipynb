# %%
x = " i am Ayan khan i am working with data science i am good man i am Ayan"

# %%
from nltk.tokenize import word_tokenize

# %%
w = word_tokenize(x)
w
# Out:
# ['i',
#  'am',
#  'Ayan',
#  'khan',
#  'i',
#  'am',
#  'working',
#  'with',
#  'data',
#  'science',
#  'i',
#  'am',
#  'good',
#  'man',
#  'i',
#  'am',
#  'Ayan']

# %%
from nltk.collocations import BigramCollocationFinder,TrigramCollocationFinder,ngrams

# %%
b = BigramCollocationFinder.from_words(w)
# t =TrigramCollocationFinder()
n = ngrams(w,2)

# %%
b.ngram_fd
# Out:
# FreqDist({('i', 'am'): 4, ('am', 'Ayan'): 2, ('Ayan', 'khan'): 1, ('khan', 'i'): 1, ('am', 'working'): 1, ('working', 'with'): 1, ('with', 'data'): 1, ('data', 'science'): 1, ('science', 'i'): 1, ('am', 'good'): 1, ...})

# %%
# t.ngram_fd

# %%
for i in n:
    print(i)
# Out:
# ('i', 'am')
# ('am', 'Ayan')
# ('Ayan', 'khan')
# ('khan', 'i')
# ('i', 'am')
# ('am', 'working')
# ('working', 'with')
# ('with', 'data')
# ('data', 'science')
# ('science', 'i')
# ('i', 'am')
# ('am', 'good')
# ('good', 'man')
# ('man', 'i')
# ('i', 'am')
# ('am', 'Ayan')
