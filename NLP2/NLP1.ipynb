# %%
x = "Natural language processingn (NLP) is a subfield of linguistics, compuer science , and artificial intelligence"

# %%
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
w = word_tokenize(x)
# Out:
# [nltk_data] Downloading package punkt to C:\Users\foziya
# [nltk_data]     khan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
w
# Out:
# ['Natural',
#  'language',
#  'processingn',
#  '(',
#  'NLP',
#  ')',
#  'is',
#  'a',
#  'subfield',
#  'of',
#  'linguistics',
#  ',',
#  'compuer',
#  'science',
#  ',',
#  'and',
#  'artificial',
#  'intelligence']

# %%
from nltk import pos_tag
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\foziya khan\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
p = pos_tag(w)
print(p)
# Out:
# [('Natural', 'JJ'), ('language', 'NN'), ('processingn', 'NN'), ('(', '('), ('NLP', 'NNP'), (')', ')'), ('is', 'VBZ'), ('a', 'DT'), ('subfield', 'NN'), ('of', 'IN'), ('linguistics', 'NNS'), (',', ','), ('compuer', 'NN'), ('science', 'NN'), (',', ','), ('and', 'CC'), ('artificial', 'JJ'), ('intelligence', 'NN')]
